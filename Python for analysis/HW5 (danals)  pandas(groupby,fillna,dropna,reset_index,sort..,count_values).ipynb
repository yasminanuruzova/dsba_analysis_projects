# %% [markdown]
# Задание 1 - Работа с файлами Data Frame
#
# - Определите, в каких столбцах есть пропущенные значения. Удалите все строки, в которых пропущено значение в столбце 'Бюджет (млн $)'.
#
# - Заполните все пропущенные значения в столбце 'Режиссер' строкой 'Неизвестен'.

# %%
import pandas as pd
df=pd.read_csv('ДЗ_Pandas.csv')
df
# Out:
#    ID              Название фильма  Год выпуска                Жанр  Рейтинг  \
# 0           1     Космический эпос         2022          Фантастика      7.8
# 1           2  Приключения времени         2020         Приключения      8.2
# 2           3        Сердце океана         2021               Драма      8.5
# 3           4     Секретные агенты         2019              Боевик      7.6
# 4           5     Загадка джунглей         2023         Приключения      7.0
# 5           6    Городские легенды         2018             Триллер      NaN
# 6           7       Звёздные врата         2023  Научная фантастика      NaN
# 7           8    Возвращение героя         2021              Боевик      7.9
# 8           9         Ночные гонки         2019               Драма      7.3
# 9          10       Тайны прошлого         2022             Мистика      7.1
#
#    Бюджет (млн $)  Сборы (млн $)        Режиссер  \
# 0           120.0            500             NaN
# 1            90.0            450  Мария Смирнова
# 2            60.0            300   Алексей Попов
# 3            85.0            550  Кирилл Соколов
# 4             NaN            350      Петр Ильин
# 5            40.0            200   Ольга Петрова
# 6           130.0            650             NaN
# 7            95.0            480  Роман Васильев
# 8             NaN            270   Елена Козлова
# 9            65.0            310  Дмитрий Иванов
#
#                      Основные актеры
# 0         Анна Петрова, Петр Сидоров
# 1     Сергей Васильев, Ольга Иванова
# 2   Дмитрий Кузнецов, Ирина Лебедева
# 3     Елена Романова, Артем Михайлов
# 4      Антон Зайцев, Марина Краснова
# 5  Игорь Николаев, Екатерина Волкова
# 6      Наталья Орлова, Антон Краснов
# 7     Максим Андреев, Алиса Горшкова
# 8     Алексей Петров, Мария Сергеева
# 9    Светлана Иванова, Денис Смирнов

# %%
df.dropna(subset=['Бюджет (млн $)'])
# Out:
#    ID              Название фильма  Год выпуска                Жанр  Рейтинг  \
# 0           1     Космический эпос         2022          Фантастика      7.8
# 1           2  Приключения времени         2020         Приключения      8.2
# 2           3        Сердце океана         2021               Драма      8.5
# 3           4     Секретные агенты         2019              Боевик      7.6
# 5           6    Городские легенды         2018             Триллер      NaN
# 6           7       Звёздные врата         2023  Научная фантастика      NaN
# 7           8    Возвращение героя         2021              Боевик      7.9
# 9          10       Тайны прошлого         2022             Мистика      7.1
#
#    Бюджет (млн $)  Сборы (млн $)        Режиссер  \
# 0           120.0            500             NaN
# 1            90.0            450  Мария Смирнова
# 2            60.0            300   Алексей Попов
# 3            85.0            550  Кирилл Соколов
# 5            40.0            200   Ольга Петрова
# 6           130.0            650             NaN
# 7            95.0            480  Роман Васильев
# 9            65.0            310  Дмитрий Иванов
#
#                      Основные актеры
# 0         Анна Петрова, Петр Сидоров
# 1     Сергей Васильев, Ольга Иванова
# 2   Дмитрий Кузнецов, Ирина Лебедева
# 3     Елена Романова, Артем Михайлов
# 5  Игорь Николаев, Екатерина Волкова
# 6      Наталья Орлова, Антон Краснов
# 7     Максим Андреев, Алиса Горшкова
# 9    Светлана Иванова, Денис Смирнов

# %%
df.fillna({'Режиссер':'Неизвестен'}, inplace=True)
df
# Out:
#    ID              Название фильма  Год выпуска                Жанр  Рейтинг  \
# 0           1     Космический эпос         2022          Фантастика      7.8
# 1           2  Приключения времени         2020         Приключения      8.2
# 2           3        Сердце океана         2021               Драма      8.5
# 3           4     Секретные агенты         2019              Боевик      7.6
# 4           5     Загадка джунглей         2023         Приключения      7.0
# 5           6    Городские легенды         2018             Триллер      NaN
# 6           7       Звёздные врата         2023  Научная фантастика      NaN
# 7           8    Возвращение героя         2021              Боевик      7.9
# 8           9         Ночные гонки         2019               Драма      7.3
# 9          10       Тайны прошлого         2022             Мистика      7.1
#
#    Бюджет (млн $)  Сборы (млн $)        Режиссер  \
# 0           120.0            500      Неизвестен
# 1            90.0            450  Мария Смирнова
# 2            60.0            300   Алексей Попов
# 3            85.0            550  Кирилл Соколов
# 4             NaN            350      Петр Ильин
# 5            40.0            200   Ольга Петрова
# 6           130.0            650      Неизвестен
# 7            95.0            480  Роман Васильев
# 8             NaN            270   Елена Козлова
# 9            65.0            310  Дмитрий Иванов
#
#                      Основные актеры
# 0         Анна Петрова, Петр Сидоров
# 1     Сергей Васильев, Ольга Иванова
# 2   Дмитрий Кузнецов, Ирина Лебедева
# 3     Елена Романова, Артем Михайлов
# 4      Антон Зайцев, Марина Краснова
# 5  Игорь Николаев, Екатерина Волкова
# 6      Наталья Орлова, Антон Краснов
# 7     Максим Андреев, Алиса Горшкова
# 8     Алексей Петров, Мария Сергеева
# 9    Светлана Иванова, Денис Смирнов

# %% [markdown]
# - Заполните все пропущенные значения в столбце 'Рейтинг' средним значением этого столбца.
#
# - Если в строке пропущены значения и в 'Бюджет (млн $)', и  в 'Сборы (млн $)', удалите эту строку. В противном случае, если пропущено значение только в одном из этих столбцов, оставьте строку.

# %%
df['Рейтинг'].fillna(df['Рейтинг'].mean(),inplace=True) # mean=7.85
df
# Out:
#    ID              Название фильма  Год выпуска                Жанр  Рейтинг  \
# 0           1     Космический эпос         2022          Фантастика    7.800
# 1           2  Приключения времени         2020         Приключения    8.200
# 2           3        Сердце океана         2021               Драма    8.500
# 3           4     Секретные агенты         2019              Боевик    7.600
# 4           5     Загадка джунглей         2023         Приключения    7.000
# 5           6    Городские легенды         2018             Триллер    7.675
# 6           7       Звёздные врата         2023  Научная фантастика    7.675
# 7           8    Возвращение героя         2021              Боевик    7.900
# 8           9         Ночные гонки         2019               Драма    7.300
# 9          10       Тайны прошлого         2022             Мистика    7.100
#
#    Бюджет (млн $)  Сборы (млн $)        Режиссер  \
# 0           120.0            500             NaN
# 1            90.0            450  Мария Смирнова
# 2            60.0            300   Алексей Попов
# 3            85.0            550  Кирилл Соколов
# 4             NaN            350      Петр Ильин
# 5            40.0            200   Ольга Петрова
# 6           130.0            650             NaN
# 7            95.0            480  Роман Васильев
# 8             NaN            270   Елена Козлова
# 9            65.0            310  Дмитрий Иванов
#
#                      Основные актеры
# 0         Анна Петрова, Петр Сидоров
# 1     Сергей Васильев, Ольга Иванова
# 2   Дмитрий Кузнецов, Ирина Лебедева
# 3     Елена Романова, Артем Михайлов
# 4      Антон Зайцев, Марина Краснова
# 5  Игорь Николаев, Екатерина Волкова
# 6      Наталья Орлова, Антон Краснов
# 7     Максим Андреев, Алиса Горшкова
# 8     Алексей Петров, Мария Сергеева
# 9    Светлана Иванова, Денис Смирнов

# %%
df.dropna(subset=['Бюджет (млн $)', 'Сборы (млн $)'])
# Out:
#    ID              Название фильма  Год выпуска                Жанр  Рейтинг  \
# 0           1     Космический эпос         2022          Фантастика    7.800
# 1           2  Приключения времени         2020         Приключения    8.200
# 2           3        Сердце океана         2021               Драма    8.500
# 3           4     Секретные агенты         2019              Боевик    7.600
# 5           6    Городские легенды         2018             Триллер    7.675
# 6           7       Звёздные врата         2023  Научная фантастика    7.675
# 7           8    Возвращение героя         2021              Боевик    7.900
# 9          10       Тайны прошлого         2022             Мистика    7.100
#
#    Бюджет (млн $)  Сборы (млн $)        Режиссер  \
# 0           120.0            500      Неизвестен
# 1            90.0            450  Мария Смирнова
# 2            60.0            300   Алексей Попов
# 3            85.0            550  Кирилл Соколов
# 5            40.0            200   Ольга Петрова
# 6           130.0            650      Неизвестен
# 7            95.0            480  Роман Васильев
# 9            65.0            310  Дмитрий Иванов
#
#                      Основные актеры
# 0         Анна Петрова, Петр Сидоров
# 1     Сергей Васильев, Ольга Иванова
# 2   Дмитрий Кузнецов, Ирина Лебедева
# 3     Елена Романова, Артем Михайлов
# 5  Игорь Николаев, Екатерина Волкова
# 6      Наталья Орлова, Антон Краснов
# 7     Максим Андреев, Алиса Горшкова
# 9    Светлана Иванова, Денис Смирнов

# %% [markdown]
# Задание 2 - Grouby
# Группировка по Жанру:
# - Сгруппируйте фильмы по жанру
# - Рассчитайте средний рейтинг и средний бюджет в каждом жанре.

# %%
df.groupby('Жанр').sum()['Название фильма'].reset_index()
# Out:
#                  Жанр                      Название фильма
# 0              Боевик    Секретные агентыВозвращение героя
# 1               Драма            Сердце океанаНочные гонки
# 2             Мистика                       Тайны прошлого
# 3  Научная фантастика                       Звёздные врата
# 4         Приключения  Приключения времениЗагадка джунглей
# 5             Триллер                    Городские легенды
# 6          Фантастика                     Космический эпос

# %%
df.groupby('Жанр').agg({'Рейтинг': 'mean', 'Бюджет (млн $)': 'mean'})
# Out:
#                     Рейтинг  Бюджет (млн $)
# Жанр
# Боевик                7.750            90.0
# Драма                 7.900            60.0
# Мистика               7.100            65.0
# Научная фантастика    7.675           130.0
# Приключения           7.600            90.0
# Триллер               7.675            40.0
# Фантастика            7.800           120.0

# %% [markdown]
# Группировка по Году Выпуска:
#
# - Сгруппируйте фильмы по году выпуска
#
# - Определите общее количество фильмов и суммарные сборы в прокате по каждому году.

# %%
df.groupby('Год выпуска').sum().reset_index()
# Out:
#    Год выпуска  ID                         Название фильма  \
# 0         2018           6               Городские легенды
# 1         2019          13    Секретные агентыНочные гонки
# 2         2020           2             Приключения времени
# 3         2021          11  Сердце океанаВозвращение героя
# 4         2022          11  Космический эпосТайны прошлого
# 5         2023          12  Загадка джунглейЗвёздные врата
#
#                             Жанр  Рейтинг  Бюджет (млн $)  Сборы (млн $)  \
# 0                        Триллер      0.0            40.0            200
# 1                    БоевикДрама     14.9            85.0            820
# 2                    Приключения      8.2            90.0            450
# 3                    ДрамаБоевик     16.4           155.0            780
# 4              ФантастикаМистика     14.9           185.0            810
# 5  ПриключенияНаучная фантастика      7.0           130.0           1000
#
#                       Режиссер  \
# 0                Ольга Петрова
# 1  Кирилл СоколовЕлена Козлова
# 2               Мария Смирнова
# 3  Алексей ПоповРоман Васильев
# 4               Дмитрий Иванов
# 5                   Петр Ильин
#
#                                      Основные актеры
# 0                  Игорь Николаев, Екатерина Волкова
# 1  Елена Романова, Артем МихайловАлексей Петров, ...
# 2                     Сергей Васильев, Ольга Иванова
# 3  Дмитрий Кузнецов, Ирина ЛебедеваМаксим Андреев...
# 4  Анна Петрова, Петр СидоровСветлана Иванова, Де...
# 5  Антон Зайцев, Марина КрасноваНаталья Орлова, А...

# %%
df.groupby('Год выпуска').agg({'Название фильма': 'count','Сборы (млн $)':sum})
# Out:
#              Название фильма  Сборы (млн $)
# Год выпуска
# 2018                       1            200
# 2019                       2            820
# 2020                       1            450
# 2021                       2            780
# 2022                       2            810
# 2023                       2           1000

# %% [markdown]
# Комбинированная Группировка:
#
# - Сгруппируйте фильмы по жанру и году выпуска
#
# - Рассчитайте средний рейтинг для каждой комбинации жанра и года выпуска

# %%
df.groupby(['Жанр','Год выпуска']).agg({'Название фильма':sum}).reset_index()
# Out:
#                  Жанр  Год выпуска      Название фильма
# 0              Боевик         2019     Секретные агенты
# 1              Боевик         2021    Возвращение героя
# 2               Драма         2019         Ночные гонки
# 3               Драма         2021        Сердце океана
# 4             Мистика         2022       Тайны прошлого
# 5  Научная фантастика         2023       Звёздные врата
# 6         Приключения         2020  Приключения времени
# 7         Приключения         2023     Загадка джунглей
# 8             Триллер         2018    Городские легенды
# 9          Фантастика         2022     Космический эпос

# %%
df.groupby(['Жанр', 'Год выпуска']).agg({'Рейтинг':'mean'})
# Out:
#                                 Рейтинг
# Жанр               Год выпуска
# Боевик             2019           7.600
#                    2021           7.900
# Драма              2019           7.300
#                    2021           8.500
# Мистика            2022           7.100
# Научная фантастика 2023           7.675
# Приключения        2020           8.200
#                    2023           7.000
# Триллер            2018           7.675
# Фантастика         2022           7.800

# %% [markdown]
# Задание 3 - reset index
#
# Группировка и Сортировка:
#
# - Сгруппируйте фильмы по жанру и рассчитайте средний рейтинг для каждого жанра
#
# - Сбросьте индекс и отсортируйте результаты по среднему рейтингу в убывающем порядке

# %%
df.groupby('Жанр').agg({'Название фильма':sum,'Рейтинг':'mean'})
# Out:
#                                         Название фильма  Рейтинг
# Жанр
# Боевик                Секретные агентыВозвращение героя    7.750
# Драма                         Сердце океанаНочные гонки    7.900
# Мистика                                  Тайны прошлого    7.100
# Научная фантастика                       Звёздные врата    7.675
# Приключения         Приключения времениЗагадка джунглей    7.600
# Триллер                               Городские легенды    7.675
# Фантастика                             Космический эпос    7.800

# %%
df.groupby('Жанр').agg({'Название фильма':sum,'Рейтинг':'mean'}).sort_values('Рейтинг', ascending=False)
# Out:
#                                         Название фильма  Рейтинг
# Жанр
# Драма                         Сердце океанаНочные гонки    7.900
# Фантастика                             Космический эпос    7.800
# Боевик                Секретные агентыВозвращение героя    7.750
# Научная фантастика                       Звёздные врата    7.675
# Триллер                               Городские легенды    7.675
# Приключения         Приключения времениЗагадка джунглей    7.600
# Мистика                                  Тайны прошлого    7.100

# %% [markdown]
# Анализ частоты:
#
# - Используйте value_counts для определения, сколько фильмов было выпущено в каждом году
#
# - Отсортируйте результаты по годам в порядке возрастания

# %%
df1=df['Год выпуска'].value_counts().reset_index()
df1
# Out:
#    Год выпуска  count
# 0         2022      2
# 1         2021      2
# 2         2019      2
# 3         2023      2
# 4         2020      1
# 5         2018      1

# %%
df['Год выпуска'].value_counts().sort_values().reset_index()
# Out:
#    Год выпуска  count
# 0         2020      1
# 1         2018      1
# 2         2022      2
# 3         2021      2
# 4         2019      2
# 5         2023      2

# %%
# Если год выпуска в порядке возрастания
df1.sort_values(by='Год выпуска',ascending=True).reset_index()
# Out:
#    index  Год выпуска  count
# 0      5         2018      1
# 1      2         2019      2
# 2      4         2020      1
# 3      1         2021      2
# 4      0         2022      2
# 5      3         2023      2

# %% [markdown]
# Комбинированный Анализ:
#
# - Сгруппируйте фильмы по режиссеру и жанру, затем рассчитайте общие сборы фильмов для каждой комбинации
#
# - Сбросьте индекс и отсортируйте результаты по сумме сборов в убывающем порядке

# %%
df2=df.groupby(['Режиссер', 'Жанр'])[['Название фильма','Сборы (млн $)']].sum().reset_index()
df2
# Out:
#          Режиссер         Жанр      Название фильма  Сборы (млн $)
# 0   Алексей Попов        Драма        Сердце океана            300
# 1  Дмитрий Иванов      Мистика       Тайны прошлого            310
# 2   Елена Козлова        Драма         Ночные гонки            270
# 3  Кирилл Соколов       Боевик     Секретные агенты            550
# 4  Мария Смирнова  Приключения  Приключения времени            450
# 5   Ольга Петрова      Триллер    Городские легенды            200
# 6      Петр Ильин  Приключения     Загадка джунглей            350
# 7  Роман Васильев       Боевик    Возвращение героя            480

# %%
df2.sort_values('Сборы (млн $)', ascending=False).reset_index()
# Out:
#    index        Режиссер         Жанр      Название фильма  Сборы (млн $)
# 0      3  Кирилл Соколов       Боевик     Секретные агенты            550
# 1      7  Роман Васильев       Боевик    Возвращение героя            480
# 2      4  Мария Смирнова  Приключения  Приключения времени            450
# 3      6      Петр Ильин  Приключения     Загадка джунглей            350
# 4      1  Дмитрий Иванов      Мистика       Тайны прошлого            310
# 5      0   Алексей Попов        Драма        Сердце океана            300
# 6      2   Елена Козлова        Драма         Ночные гонки            270
# 7      5   Ольга Петрова      Триллер    Городские легенды            200
